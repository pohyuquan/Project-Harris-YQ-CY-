# %%
import pandas as pd

# %%
pd.read_csv("va_presidential.csv")
# Out:
#                County/City  Democratic  Republican  Total Votes Cast  Year  \
# 0          Accomack County        2087         307              2426  1924
# 1         Albemarle County        1383         366              1801  1924
# 2          Alexandria City        1136         556              1958  1924
# 3         Alleghany County         589         856              1628  1924
# 4            Amelia County         372         153               540  1924
# 5           Amherst County        1092         129              1326  1924
# 6        Appomattox County         952         101              1071  1924
# 7         Arlington County        1209        1307              2921  1924
# 8           Augusta County        1920        1265              3263  1924
# 9              Bath County         404         407               835  1924
# 10          Bedford County        1811         432              2274  1924
# ...

# %%
df = pd.read_csv("va_presidential.csv")

# %%
df[df["County/City"].str.lower() == "Richmond".lower()+ " county".lower()]
# Out:
#           County/City  Democratic  Republican  Total Votes Cast  Year  \
# 95    Richmond County         340         125               471  1924
# 219   Richmond County         292         467               759  1928
# 344   Richmond County         461         192               659  1932
# 469   Richmond County         451         217               668  1936
# 594   Richmond County         475         257               741  1940
# 719   Richmond County         364         336               701  1944
# 844   Richmond County         240         296               615  1948
# 971   Richmond County         326         727              1055  1952
# 1102  Richmond County         274         761              1121  1956
# 1233  Richmond County         425         801              1233  1960
# 1365  Richmond County         636         901              1540  1964
# 1499  Richmond County         490        1011              2069  1968
# ...

# %%
df[df["County/City"].str.lower()  "Richmond".lower()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-072349dd969b> in <module>()
# ----> 1 df[df["County/City".contains(str.lower(city))].str.lower]
#
# AttributeError: 'str' object has no attribute 'contains'

# %%
df[df["County/City"].str.lower().str.contains(str.lower("Suffolk"))]
# Out:
#               County/City  Democratic  Republican  Total Votes Cast  Year  \
# 110          Suffolk City         557         179               760  1924
# 234          Suffolk City         637         573              1210  1928
# 359          Suffolk City        1013         265              1287  1932
# 484          Suffolk City        1360         281              1641  1936
# 609          Suffolk City        1215         383              1598  1940
# 734          Suffolk City        1342         569              1914  1944
# 859          Suffolk City        1030         741              2070  1948
# 986          Suffolk City        1209        1622              2837  1952
# 1117         Suffolk City        1103        1617              2812  1956
# 1249         Suffolk City        1419        1406              2834  1960
# 1380         Suffolk City        1579        1463              3044  1964
# 1515         Suffolk City        1044        1277              3365  1968
# ...

# %%
df.apply(lambda x: x['a'] in x['b'], axis=1)
df[df['A'].str.contains("hello")]
private["ISH"] = private.HolidayName.str.lower().str.contains("holiday|recess")
